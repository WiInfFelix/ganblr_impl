# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
superstore = pd.read_csv("./datasets/SampleSuperstore.csv")

# %%
# print columns name and data type
print(superstore.dtypes)
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
plt.plot(superstore.Profit.unique())
plt.show()
